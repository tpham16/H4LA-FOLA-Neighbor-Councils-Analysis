# %%
import pandas as pd

# %%
df = pd.read_csv("data/foodoasis - foodoasis.csv")

# %%
df.head()
# Out:
#      ID                                               Name  \
# 0  4489                                        A Plus ADHC
# 1  4285                           Calvary Chapel - Emanuel
# 2  3185                              Vision of Hope Church
# 3  4403  Our Redeemer Lutheran Church (Human Care Minis...
# 4  4728                     Los Angeles Regional Food Bank
#
#    Closed Permanently  Closed for COVID  \
# 0                 1.0               NaN
# 1                 1.0               NaN
# 2                 NaN               NaN
# 3                 NaN               NaN
# 4                 NaN               NaN
#
#                                          Covid Notes  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                 Open during COVID for grab and go.
# 4  Food Bank operations are continuing with no ma...
#
# ...

# %%
df[]
